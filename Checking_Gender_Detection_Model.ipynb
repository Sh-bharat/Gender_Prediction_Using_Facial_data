# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np
from tensorflow import keras
# Out:
# WARNING:tensorflow:From C:\Users\bhara\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model=keras.models.load_model('Gender_detection_model.keras')
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\bhara\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\bhara\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\bhara\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_25 (Conv2D)          (None, 254, 254, 32)      896
#
#  max_pooling2d_24 (MaxPooli  (None, 127, 127, 32)      0
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 125, 125, 64)      18496
#
# ...

# %%
## Testing on Image
img=cv2.imread("C:\\Users\\bhara\\11\\M3.jpg")
haar_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
import matplotlib.pyplot as plt
plt.imshow(img[:,:,::-1])

# %%
faces_rect = haar_cascade.detectMultiScale(gray_img, 1.1, 9)
try :
    if(faces_rect!=()):
        for(x,y,w,h) in faces_rect:
            output=img[y:y+h,x:x+w,:]
            output_img=cv2.resize(output,(256,256))
            plt.imshow(output_img[:,:,::-1])
        image = tf.keras.preprocessing.image.img_to_array(output_img)
        image = np.expand_dims(image, axis=0)
        prediction = model.predict(image)

        if (np.argmax(prediction)==0):
          print("The image is a Female.")
        else:
          print("The image is a Male.")
except Exception as e:
    print("Can't Detect Face")

# %%
## For Live Testing
import numpy as np
import cv2
import math
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Error: Camera can not be opened. ")
while True:
    ret, frame = cap.read()
    gray_img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
    img=frame
    haar_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")     
    faces_rect = haar_cascade.detectMultiScale(gray_img, 1.1, 9)
    for(x,y,w,h) in faces_rect:       
        output=img[y:y+h,x:x+w,:]
        output_img=cv2.resize(output,(256,256))
        image = tf.keras.preprocessing.image.img_to_array(output_img)
        image = np.expand_dims(image, axis=0)
        prediction = model.predict(image)
        if (np.argmax(prediction)==0):
            Gender='Female'
        else:
            Gender='Male'
        cv2.putText(frame,Gender,(x,y),cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0),1,cv2.LINE_AA)
    cv2.imshow('Camera', frame)
    
    c = cv2.waitKey(1)
    if c == 27: # For Esc character
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 33ms/step
